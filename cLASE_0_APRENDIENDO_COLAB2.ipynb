# %% [markdown]
# <a href="https://colab.research.google.com/github/jrojas443-create/PROGCOM-A-2026/blob/main/cLASE_0_APRENDIENDO_COLAB2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# if (condicion)==verdadera
# print("pasan cositas")
# else:
# print("pasan otras cositas")
#
# ```
#
#
#
# ##aprendiendo a usar print
# print() es un metodo que permite imprimir informacion de consola

# %% [markdown]
# el print () puede imprimir lo siguiente
# 1. Cualquier tipo de dato
# 2. Cualquier metodo o funsion (su direccion en memoria)
# 3. Concatenacion de texto
# 4. Operaciones matematicas

# %% [markdown]
# ##conociendo el input
# input () es un metodo con triple funcion
# * declara: toda la informacion que ingresa coneste metodo, se declara
# automaticamente como string (caracter).
# * lee: porque

# %%
x=int(input("ingrese su edad"))
y=input("ingrese su nombre:")
print(y,"tiene una edad de",x)
# Out:
# ingrese su edad12
# ingrese su nombre:oi
# oi tiene una edad de 12

# %% [markdown]
# ###concatenacion
# concatenar es unir dos tipos de datos
